# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install opendatasets

# %%
import opendatasets as od
dataset_url = 'https://www.kaggle.com/competitions/state-farm-distracted-driver-detection/data'
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: alizayadahmadriyaz
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 4.00G/4.00G [00:40<00:00, 105MB/s]
# Extracting archive ./state-farm-distracted-driver-detection/state-farm-distracted-driver-detection.zip to ./state-farm-distracted-driver-detection

# %%
import keras

# %%
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import Sequential
from keras.applications.mobilenet import MobileNet

# %%
conv_base=MobileNet(alpha=1.0,
    dropout=0.001,
    include_top=False,
    weights="imagenet",
    classifier_activation="softmax")
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
conv_base.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv1 (Conv2D)              (None, None, None, 32)    864
#
#  conv1_bn (BatchNormalizatio  (None, None, None, 32)   128
#  n)
#
#  conv1_relu (ReLU)           (None, None, None, 32)    0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, None, None, 32)   288
#
#  conv_dw_1_bn (BatchNormaliz  (None, None, None, 32)   128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, None, None, 32)    0
#
#  conv_pw_1 (Conv2D)          (None, None, None, 64)    2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, None, None, 64)   256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, None, None, 64)    0
#
#  conv_pad_2 (ZeroPadding2D)  (None, None, None, 64)    0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, None, None, 64)   576
#
#  conv_dw_2_bn (BatchNormaliz  (None, None, None, 64)   256
# ...

# %%
from keras.applications.mobilenet import preprocess_input

# %%
model=Sequential()
model.add(conv_base)
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer="Adam",loss=tf.keras.losses.CategoricalCrossentropy(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, None, None, 1024)  3228864
#  nal)
#
#  dense (Dense)               (None, None, None, 128)   131200
#
#  dense_1 (Dense)             (None, None, None, 10)    1290
#
# ...
# Total params: 3,361,354
# Trainable params: 132,490
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
conv_base.trainable=False

# %%
train_datagen=ImageDataGenerator(
     zoom_range=0.2,
    rotation_range=20,
     horizontal_flip=True,validation_split=0.2,rescale=)
test_datagen=ImageDataGenerator()
train_data=train_datagen.flow_from_directory('/content/state-farm-distracted-driver-detection/imgs/train',target_size=(224,224),batch_size=32,class_mode='categorical')
validation_data=test_datagen.flow_from_directory('/content/state-farm-distracted-driver-detection/imgs/test',target_size=(224,224),batch_size=32,class_mode='categorical')
# Out:
# Found 22424 images belonging to 10 classes.
# Found 0 images belonging to 0 classes.

# %%
train_data=preprocess_input(train_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-61f1e9ff8d27> in <cell line: 1>()
# ----> 1 train_data=preprocess_input(train_data)
#
# /usr/local/lib/python3.10/dist-packages/keras/applications/mobilenet.py in preprocess_input(x, data_format)
#     471 @keras_export("keras.applications.mobilenet.preprocess_input")
#     472 def preprocess_input(x, data_format=None):
# --> 473     return imagenet_utils.preprocess_input(
#     474         x, data_format=data_format, mode="tf"
#     475     )
#
# /usr/local/lib/python3.10/dist-packages/keras/applications/imagenet_utils.py in preprocess_input(x, data_format, mode)
#     121         return _preprocess_numpy_input(x, data_format=data_format, mode=mode)
#     122     else:
# --> 123         return _preprocess_symbolic_input(x, data_format=data_format, mode=mode)
#     124
#     125
#
# ...

# %%
def process(image)
# Out:
#   File "<ipython-input-14-e4f2e14394bb>", line 1
#     def process(image)
#                       ^
# SyntaxError: expected ':'

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dense_1 (Dense)             (None, 10)                5130
#
# ...
# Total params: 18914634 (72.15 MB)
# Trainable params: 4199946 (16.02 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
model.fit_generator(train_data,epochs=10,use_multiprocessing=True)
# Out:
# <ipython-input-17-37dd07ea36a3>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_data,epochs=2)
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1862: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# Epoch 1/2
# 701/701 [==============================] - 4310s 6s/step - loss: 0.8834 - accuracy: 0.8123
# Epoch 2/2
# 465/701 [==================>...........] - ETA: 24:25 - loss: 0.2092 - accuracy: 0.9398

# %%
# !pip install tensorpack
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# !pip install utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13905 sha256=2d136572f24567405d6eebd0236dba3992363f9a0e0f69455af05fb1feb5d122
#   Stored in directory: /root/.cache/pip/wheels/b8/39/f5/9d0ca31dba85773ececf0a7f5469f18810e1c8a8ed9da28ca7
# Successfully built utils
# ...

# %%
# !pip install tensorpack
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 2.5 MB/s eta 0:00:00
# ...
